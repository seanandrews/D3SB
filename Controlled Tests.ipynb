# %% [markdown]
# # Controlled Tests

# %% [markdown]
# Ok, so in the "concepts" notebook I explained the basic premise of the "agnostic" discretized model of the surface brightness distribution.  Now I want to see if this actually will work in practice.  To start, I generated a fake dataset where I know the true intensity profile.  There is noise in the data, in that each visibility point comes attached with an uncertainty, but the underlying datapoints have not actually been perturbed from their true amplitudes.  I think of this as a (very) controlled test of the ability for "recovery" in the inference approach.
#
# The underlying model is a similarity solution brightness profile,
#
# $I(r) = A \, \left( \frac{r}{r_c} \right)^{-\gamma} \exp{\left[-\left(\frac{r}{r_c}\right)^{2-\gamma}\right]}$
#
# for a set of parameters $\{A, \, r_c, \, \gamma\}$ that denote an overall normalization, characteristic radius, and index.  This is perhaps a challenging first test, since it spans logarithmic scales in radius, but it should be vaguely representative of real disk behavior.
#
# First I define the "true" model parameters:

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

dpc = 140.
nr = 500
ftot = 0.1
rc  = 35./dpc
gam = 1.0
A = (2.-gam)*ftot/(2.*np.pi*rc**2)
r  = np.logspace(-2, 1, num=nr)
Ir = A * (r/rc)**(-gam) * np.exp(-(r/rc)**(2.-gam))

# %% [markdown]
# Separately, I generated a high resolution model image with this brightness profile, assuming a face-on orientation (since I have yet to incorporate projection into the model).  This was then Fourier transformed and sparsely sampled onto a set of visibility measurements (in this case, the CARMA 1.3mm GG Tau data from my recent paper; just what I had lying around).  The "noise" (visibility weights) is preserved from that dataset in this process.
#
# I can retrieve that fake visibility data:

# %%
from get_vis import get_vis

data = get_vis('model.vis.fits')
u, v, dreal, dimag, dwgt = data
rho = np.sqrt(u**2+v**2)

# %% [markdown]
# The success of this approach probably hinges (considerably) on an appropriate selection of the discretization; i.e., how we select the radial bins on which to define the model.  The optimized approach for doing this is not yet obvious to me.  Clearly we want to choose enough bins to capture variations in the brightness profile, but not too many that we can't constrain their amplitudes with the data (the computing time itself scales ~linearly with the number of bins we adopt; maybe that could be improved, but I'm not sure how).  To start, I'm experimenting with simple linear bins:

# %%
# choose radial bins: b is the outer edge (passed)
# a (inner edge) and cb (center) are also defined for plotting purposes
nbins = 20
b = np.linspace(0.05, 2., num=nbins)
a = np.roll(b, 1)
rin = 0.01/140.
a[0] = rin
cb = 0.5*(a+b)

# to be passed to model routine
bins = rin, b

# %% [markdown]
# Now I want to define the discretized amplitudes I *should* get if the code ran perfectly, written below as $\{w_0\}$.  And I also have to define a starting "guess" to initialize the MCMC routine.  I think in the end what I'll do is use a radial projection of the synthesized image to do this, but to start I have just done a Gaussian fit to the fake data in the Fourier plane, and applied those to the guess amplitudes $\{w_g\}$.  I have tweaked the actual model code to deal in log(amplitude), so that I don't need a positivity prior.  This means that I need to force $\{w_g\}$ to a negligibly low value when it might otherwise go to zero at large $r$.

# %%
# true discretized amplitudes
w0 = A*(cb/rc)**(-gam)*np.exp(-(cb/rc)**(2-gam))

# initial guess based on Gaussian fit to fake visibilities
sig = 0.15
nrm = 0.1/(2.*np.pi*sig**2)
wg = nrm*np.exp(-0.5*(cb/sig)**2)
wg[wg <= 1e-11] = 1e-11

# %% [markdown]
# Now I can check and see how this all goes together.  First I compute the visibilities for the discrete models (both "true" and "guess"), and compare them to the fake dataset through their $\chi^2$ values.  Then I plot up the comparisons: (top left) brightness profiles in log-log with black = true, gray = true but discretized, green = discretized guess; (top right) visibilities (unbinned) with error bars in blue, and corresponding models; (bottom left) same as top left but on a linear scale; and (bottom right) same as top right, but now showing just the fake visibility amplitudes (and not their corresponding errors) in blue, for clarity.

# %%
from d3sb_model import d3sb_model
from lnprob import lnprob

# run the D3SB to get visibility models
uvsamples = u, v
vis0 = d3sb_model(np.log10(w0), uvsamples, bins)
visg = d3sb_model(np.log10(wg), uvsamples, bins)

# compute and print the chi2 values
prob0 = lnprob(np.log10(w0), data, bins)
probg = lnprob(np.log10(wg), data, bins)
print(-2.*prob0, -2.*probg)

# plot the results
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].axis([0.01, 10, 1e-12, 27])
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].plot(r, Ir, 'black', cb, w0, 'ro', cb, wg, 'go')
ax[0].set_xlabel('angle [arcsec]')
ax[0].set_ylabel('intensity [Jy/arcsec2]')
ax[1].axis([0, 650, -0.5, 0.6])  
ax[1].plot(rho, visg, 'g.', rho, vis0, 'r.', np.arange(650), np.zeros_like(np.arange(650)), 'k--')
ax[1].errorbar(rho, dreal, yerr=np.sqrt(1./dwgt), ecolor='b', fmt='.r', alpha=0.003)
ax[1].set_xlabel('angular frequency [klambda]')
ax[1].set_ylabel('real flux [Jy]')

fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].axis([0.0, 1.5, 1e-12, 27.])
ax[0].set_yscale('log')
ax[0].plot(r, Ir, 'black', cb, w0, 'ro', cb, wg, 'go')
ax[0].set_xlabel('angle [arcsec]')
ax[0].set_ylabel('intensity [Jy/arcsec2]')
ax[0].plot(r, Ir, 'black', cb, w0, 'ro', cb, wg, 'go')
ax[1].axis([0, 650, -0.1*np.amax(dreal), 1.1*np.amax(dreal)])
ax[1].plot(rho, visg, 'g.', rho, vis0, 'r.', rho, dreal, 'b.', np.arange(650), np.zeros_like(np.arange(650)), 'k--')
ax[1].set_xlabel('angular frequency [klambda]')
ax[1].set_ylabel('real flux [Jy]')
# Out:
# (0.99561239693079329, 52.638723013516504)

# %% [markdown]
# Now we can run an MCMC simulation with $emcee$ to see if we can recover the "true" surface brightness distribution:

# %%
import emcee
from lnprob import lnprob

# set up walkers
ndim, nwalkers, nthreads = nbins, 80, 8
p0 = np.array(np.log10(w0))
p0 = [p0 + np.random.randn(ndim)*1.0 for i in range(nwalkers)]

# initialize sampler
sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, threads=nthreads, args=[data, bins])

# run emcee
# %time sampler.run_mcmc(p0, 100)
# Out:
# CPU times: user 11.9 s, sys: 7.03 s, total: 18.9 s
# Wall time: 39min 36s
# (array([[ 0.35151461, -0.42699108, -0.9651729 , ..., -4.40055082,
#          -4.10428579, -4.74210675],
#         [ 0.16760243, -0.05208856, -1.74660551, ..., -4.45046126,
#          -4.28966881, -4.86975038],
#         [ 0.03304846, -0.2007944 , -1.1048768 , ..., -4.59825074,
#          -4.36458098, -4.82892967],
#         ...,
#         [ 0.57713307, -0.54202659, -0.85686508, ..., -5.30763772,
#          -3.80603772, -6.30843908],
#         [ 0.2520133 , -0.26964937, -0.86883065, ..., -4.57225405,
#          -4.26160554, -5.36661953],
#         [ 0.08903032, -0.09328316, -1.74801534, ..., -4.16219452,
#          -4.23976823, -4.88459782]]),
#  array([ -1.42480919e+01,  -2.33802852e+01,  -3.33603383e+00,
#          -7.81213379e+00,  -4.01808342e+00,  -1.10894864e+01,
#          -5.55229065e+00,  -4.06872709e+00,  -1.00643933e+01,
#          -4.64106372e+00,  -6.36774550e+00,  -3.21766293e+00,
#          -1.11640812e+01,  -2.71447652e+00,  -6.74124311e+00,
#          -2.21220824e+00,  -5.02882384e+00,  -2.31059882e+00,
#           752903202, 2638873384, 1417152943, 1522116632, 4193769384,
#          1580879943, 3678525128, 2846311327,  566391488, 3645645537,
#          1351396125, 2423996884, 2697183609, 1062374322, 2185348941,
#          4135237655,  239199546, 4184326457, 1569049353,   22538334,
#          1680072809,   66780600,  133108381, 3297988594,  157456153,
#           288219469, 3623912668, 2624363725, 3604333743,  863093231,
#          4224559597, 3181643945, 1712083580, 1728909277, 3729071350,
#          1325343094, 2241822683, 3796061180, 1259436003, 1844779943,
#          2015717815, 1432305287, 1074816950, 2690124184,  201975261,
#          1933530617, 1473079181,  304051103, 3530964431, 2046130790,
#          3767537092, 3669159863, 2823867122, 1309019640, 3103003039,
#          3109191780, 2829671598, 1828873581, 2906271737,  196952783,
#           931989233, 2729676241, 2745775716, 2906526979,  551933975,
#           697652615, 2206720402, 2290415612, 2050587730, 1731942973,
#          2094165413,  955966867, 4112377438, 3954003415, 1267859118,
#          2242165959, 2692419984, 1035695180, 3530360496, 1368246647,
#          2813015744,   93248102, 2170452972,  690040409, 3747113414,
#           539679208, 1106941177, 2771660269, 3868294943, 2745435807,
#           512625989, 1563698533, 1178701759, 1339477180, 2463678769,
#          2191303030,  366315906,  258489333,  999277711, 3437176580,
#          3815834192,  471868991, 2838687821, 1384442933, 4083950941,
#           283092809, 2509505072,  440498473, 1318054222, 1441591558,
#          1424141195, 2828652720,   33342286, 3346774331, 2793349085,
#          3389343758,  907838006, 3493371893,  224155961,  947692043,
#          1998723513,  369209320, 2191970945, 3733501376, 2408918476,
#          3405176674, 1268077615, 2954341171, 3706853927,  979925996,
#          1070370175, 1372322535,   49546637, 3176361831, 2359039892,
#          3369566580, 3977807152,  114151783, 1395934838,  175768741,
#          3659792465, 2227058833, 1219494405, 2162726897,  103207638,
#          2800269340, 3319569234,  349662387,  139667684, 2310326979,
#           202077798,  725552523, 1627138779, 1758313510, 3462374121,
#          2541726539, 1699934652, 1568007802, 3109978036, 1181362239,
#          3946384426, 4124300693,  628378868, 4046443925, 3633218848,
#          3523895295, 1517764940,  167710125, 1434966972,  359198238,
#           810721737,  748717777, 3106841457, 3563508803, 1652621715,
#          1255495566, 2166986774,   48956560, 3377721876,  751409903,
#           664349288,  402318703, 2883315438,  282807369,  554600291,
#          1136162003, 1960579584, 2286627280, 2170979421, 1758988083,
#          2969023550, 1368404428, 3608184890, 1376536000, 2050396161,
#          2401221413, 2940708921,  225736735, 3325316319, 2718625685,
#          2866539126,  314391208, 1383272452, 3165846093, 3265550218,
#          1167433732, 1717870861,  403388723, 3152683095], dtype=uint32), 596, 0, 0.0))

# %% [markdown]
# Now we want to take a look at those results compared to the "true" situation:

# %%
from astropy.io import ascii
from astropy.table import Table

# reshape the chain output
trace = sampler.chain.reshape(-1, ndim)

# for sanity, store the output in an ASCII file
output = Table(trace)
ascii.write(output, 'trace_ex.txt')

# trim off the burn-in
tr = trace[1000:, :]

# set up a plot
plt.axis([0.0, 1.5, 1e-12, 27])
plt.yscale('log')
plt.set_xlabel('angle [arcsec]')
plt.set_ylabel('intensity [Jy/arcsec2]')

# draw randomly from posteriors and plot
for i in np.random.randint(len(tr), size=100):
    amps = tr[i][:]
    plt.plot(cb, 10.**amps, color="k", alpha=0.03)
    
plt.plot(r, Ir, 'black', cb, w0, 'ro', cb, wg, 'go')
