# %% [markdown]
# # Controlled Tests

# %% [markdown]
# Ok, so in the "concepts" notebook I explained the basic premise of the "agnostic" discretized model of the surface brightness distribution.  Now I want to see if this actually will work in practice.  To start, I generated a fake dataset where I know the true intensity profile.  There is noise in the data, in that each visibility point comes attached with an uncertainty, but the underlying datapoints have not actually been perturbed from their true amplitudes.  I think of this as a (very) controlled test of the ability for "recovery" in the inference approach.
#
# The underlying model is a similarity solution brightness profile,
#
# $I(r) = A \, \left( \frac{r}{r_c} \right)^{-\gamma} \exp{\left[-\left(\frac{r}{r_c}\right)^{2-\gamma}\right]}$
#
# for a set of parameters $\{A, \, r_c, \, \gamma\}$ that denote an overall normalization, characteristic radius, and index.  This is perhaps a challenging first test, since it spans logarithmic scales in radius, but it should be vaguely representative of real disk behavior.
#
# First I define the "true" model parameters:

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

dpc = 140.
nr = 500
ftot = 0.1
rc  = 35./dpc
gam = 1.0
A = (2.-gam)*ftot/(2.*np.pi*rc**2)
r  = np.logspace(-2, 1, num=nr)
Ir = A * (r/rc)**(-gam) * np.exp(-(r/rc)**(2.-gam))

# %% [markdown]
# Separately, I generated a high resolution model image with this brightness profile, assuming a face-on orientation (since I have yet to incorporate projection into the model).  This was then Fourier transformed and sparsely sampled onto a set of visibility measurements (in this case, the CARMA 1.3mm GG Tau data from my recent paper; just what I had lying around).  The "noise" (visibility weights) is preserved from that dataset in this process.
#
# I can retrieve that fake visibility data:

# %%
from get_vis import get_vis

data = get_vis('model.vis.fits')
u, v, dreal, dimag, dwgt = data
rho = np.sqrt(u**2+v**2)

# %% [markdown]
# The success of this approach probably hinges (considerably) on an appropriate selection of the discretization; i.e., how we select the radial bins on which to define the model.  The optimized approach for doing this is not yet obvious to me.  Clearly we want to choose enough bins to capture variations in the brightness profile, but not too many that we can't constrain their amplitudes with the data (the computing time itself scales ~linearly with the number of bins we adopt; maybe that could be improved, but I'm not sure how).  To start, I'm experimenting with simple linear bins:

# %%
# choose radial bins: b is the outer edge (passed)
# a (inner edge) and cb (center) are also defined for plotting purposes
nbins = 20
b = np.linspace(0.05, 2., num=nbins)
a = np.roll(b, 1)
rin = 0.01/140.
a[0] = rin
cb = 0.5*(a+b)

# to be passed to model routine
bins = rin, b

# %% [markdown]
# Now I want to define the discretized amplitudes I *should* get if the code ran perfectly, written below as $\{w_0\}$.  And I also have to define a starting "guess" to initialize the MCMC routine.  I think in the end what I'll do is use a radial projection of the synthesized image to do this, but to start I have just done a Gaussian fit to the fake data in the Fourier plane, and applied those to the guess amplitudes $\{w_g\}$.  I have tweaked the actual model code to deal in log(amplitude), so that I don't need a positivity prior.  This means that I need to force $\{w_g\}$ to a negligibly low value when it might otherwise go to zero at large $r$.

# %%
# true discretized amplitudes
w0 = A*(cb/rc)**(-gam)*np.exp(-(cb/rc)**(2-gam))

# initial guess based on Gaussian fit to fake visibilities
sig = 0.15
nrm = 0.1/(2.*np.pi*sig**2)
wg = nrm*np.exp(-0.5*(cb/sig)**2)
wg[wg <= 1e-11] = 1e-11

# %% [markdown]
# Now I can check and see how this all goes together.  First I compute the visibilities for the discrete models (both "true" and "guess"), and compare them to the fake dataset through their $\chi^2$ values.  Then I plot up the comparisons: (top left) brightness profiles in log-log with black = true, gray = true but discretized, green = discretized guess; (top right) visibilities (unbinned) with error bars in blue, and corresponding models; (bottom left) same as top left but on a linear scale; and (bottom right) same as top right, but now showing just the fake visibility amplitudes (and not their corresponding errors) in blue, for clarity.

# %%
from d3sb_model import d3sb_model
from lnprob import lnprob

# run the D3SB to get visibility models
uvsamples = u, v
vis0 = d3sb_model(np.log10(w0), uvsamples, bins)
visg = d3sb_model(np.log10(wg), uvsamples, bins)

# compute and print the chi2 values
prob0 = lnprob(np.log10(w0), data, bins)
probg = lnprob(np.log10(wg), data, bins)
print(-2.*prob0, -2.*probg)

# plot the results
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].axis([0.01, 10, 1e-12, 27])
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].plot(r, Ir, 'black', cb, w0, 'ro', cb, wg, 'go')
ax[0].set_xlabel('angle [arcsec]')
ax[0].set_ylabel('intensity [Jy/arcsec2]')
ax[1].axis([0, 650, -0.5, 0.6])  
ax[1].plot(rho, visg, 'g.', rho, vis0, 'r.', np.arange(650), np.zeros_like(np.arange(650)), 'k--')
ax[1].errorbar(rho, dreal, yerr=np.sqrt(1./dwgt), ecolor='b', fmt='.r', alpha=0.003)
ax[1].set_xlabel('angular frequency [klambda]')
ax[1].set_ylabel('real flux [Jy]')

fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].axis([0.0, 1.5, 1e-12, 27.])
ax[0].set_yscale('log')
ax[0].plot(r, Ir, 'black', cb, w0, 'ro', cb, wg, 'go')
ax[0].set_xlabel('angle [arcsec]')
ax[0].set_ylabel('intensity [Jy/arcsec2]')
ax[0].plot(r, Ir, 'black', cb, w0, 'ro', cb, wg, 'go')
ax[1].axis([0, 650, -0.1*np.amax(dreal), 1.1*np.amax(dreal)])
ax[1].plot(rho, visg, 'g.', rho, vis0, 'r.', rho, dreal, 'b.', np.arange(650), np.zeros_like(np.arange(650)), 'k--')
ax[1].set_xlabel('angular frequency [klambda]')
ax[1].set_ylabel('real flux [Jy]')
# Out:
# (0.99561239693078996, 52.638723013516532)

# %% [markdown]
# Now we can run an MCMC simulation with $emcee$ to see if we can recover the "true" surface brightness distribution:

# %%
import emcee
from lnprob import lnprob

# set up walkers
ndim, nwalkers, nthreads = nbins, 80, 8
p0 = np.array(np.log10(w0))
p0 = [p0 + np.random.randn(ndim)*1.0 for i in range(nwalkers)]

# initialize sampler
sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, threads=nthreads, args=[data, bins])

# run emcee
# %time sampler.run_mcmc(p0, 100)
# Out:
# CPU times: user 9.39 s, sys: 7.18 s, total: 16.6 s
# Wall time: 2min 24s
# (array([[ 0.25655148, -0.29634357, -1.18538107, ..., -3.24776516,
#          -5.83914895, -5.42880684],
#         [-0.29553645, -0.15958141, -0.68209713, ..., -4.37147029,
#          -5.68926962, -4.04211927],
#         [ 0.01262439, -0.15259575, -1.02151253, ..., -4.51789588,
#          -5.06957268, -3.80090557],
#         ...,
#         [ 0.59122496, -0.69894829, -1.18711167, ..., -4.3881104 ,
#          -5.11885374, -5.24240541],
#         [-0.05685049, -0.18705331, -1.3769212 , ..., -4.05678327,
#          -4.33640419, -4.83802708],
#         [ 0.65971225, -0.9736122 , -0.85760458, ..., -3.87555528,
#          -5.42293738, -4.84762916]]),
#  array([ -4.73168264e+00,  -5.36995438e+00,  -5.09988835e+00,
#          -3.30286063e-01,  -5.32480026e+00,  -8.67907370e+00,
#          -6.55167248e+00,  -1.83320926e+01,  -6.33767903e+00,
#          -2.30390806e+00,  -1.71508360e+00,  -1.36768183e+01,
#          -1.13639774e+00,  -8.64609346e+00,  -6.48905181e+00,
#          -5.26896615e+00,  -6.92694643e+00,  -1.62933838e+00,
#          -4.88837881e+00,  -5.00440899e+00,  -6.42204817e+00,
#          -2.30372441e+00,  -5.22866234e+00,  -7.99632116e+00,
#          -1.33901196e+01,  -3.32458365e+00,  -1.59462086e+01,
#          -1.13623290e+01,  -5.53485403e+00,  -9.69153898e+00,
#          -1.31673251e+01,  -7.18285969e+00,  -4.02780237e+00,
#          -6.48513722e+00,  -2.18309949e+00,  -4.46929063e+00,
#          -1.02085557e+01,  -9.49523982e+00,  -3.89064539e+00,
#          -2.50356244e+00,  -4.20050489e+00,  -4.84600339e+01,
#          -7.71243847e+00,  -2.49767801e+01,  -5.01989995e+00,
#          -3.70171532e+00,  -5.95467221e+00,  -3.42150475e+00,
#          -7.43783462e+00,  -9.80876297e+00,  -5.57777354e+00,
#          -4.15283986e+00,  -5.04440668e+00,  -5.66749859e+02,
#          -3.02696731e+00,  -7.89169378e+00,  -1.21731930e+01,
#          -6.53892442e+00,  -6.29608175e+00,  -5.31452512e+00,
#          -9.19715999e+00,  -6.51551599e+00,  -7.18688478e+00,
#          -1.46149036e+01,  -4.52355132e+00,  -8.93794877e+00,
#          -1.52557791e+01,  -3.97256976e+00,  -2.04694923e+00,
#          -8.89589655e+00,  -1.43704215e+00,  -1.01190619e+01,
#          -6.95366944e+00,  -1.09395518e+01,  -3.17057523e+01,
#          -1.09135680e+01,  -4.26198307e+00,  -8.66449003e+00,
#          -9.33711598e+00,  -4.28469344e+00]),
#  ('MT19937', array([3511961349, 4144221344, 1876713078, 4161229246,  896323598,
#          3793120605, 3949747468, 3936932334, 1082828439, 3914860547,
#           320609863, 1798987025, 1259714908, 2573393866, 2502148048,
#          3027183183, 3874104888, 1018250461, 3519594216, 2642864774,
#          2183834320,  762124374,  325019788, 2866940038, 1893444230,
#          4026132600,  965610087, 1321653049, 2268019250, 1602082908,
#          1628287034,  523363711, 2907353398, 3619283298, 1991104752,
#           526775912, 1685388195, 1831039337, 2225662917,  294041726,
#          3563071107, 4293889297, 1126260971, 3927278116, 3079467957,
#          1415435390, 2810738462, 1318621759,  396472036, 4171199912,
#          3092093180, 3585015372, 3240325276, 4251111179,  409207375,
#          1236691908, 3881512363,  187831350,  650166422, 2261346129,
#          1277006568, 1837775979,  637969677,  944642521,  143703163,
#          1892093150, 2970729748,  223989387,  775012166, 3152594961,
#          2506276576, 2083882958,  359723992, 2445917750,  339498010,
#          1089107982, 1069549758, 1180395768, 3405510292, 1846016612,
#          3546460822, 2442818922,  522243316,  341880508, 3016297019,
#           764094234,  835167641, 1983493281,  882581470, 3778713249,
#          2967281564, 3188915709, 3487795077, 2303499896,  500572320,
#          3466365283, 2585774201, 3023973220,  235356259, 2405509209,
#          2270482186, 1586770351,  584066007, 1672480274, 2681586409,
#          1141178702, 3002818801, 1637657281, 3577116423, 3590130943,
#           480112699, 3034173830,   14592991,  415324179, 1604233850,
#          2353163051, 1458464107, 2067155706, 1548746382, 1699142195,
#          2503038764,  435631711, 3457205610, 2818495102, 1808974238,
#          1149091536,  916086202, 3995017341, 1473997012, 3627887075,
#           702244022,  396956738, 3964902532, 3582468095,  858975975,
#          3581701106, 2192652370,  914663960, 1331280287, 1307691558,
#          1896244947, 3858099894, 1545753475, 3953199073, 1223293363,
#          4002701291,  252519642, 2375754927,  486603129, 2424777933,
#           400808977, 3355784724, 1299219785,  743425830, 2768764632,
#          3356421646,  556404998, 1382354394, 2687723194, 1681391241,
#          2220542688, 4168086064, 2101426568, 1203118469,  772076816,
#          1584395428,  681758716,    2499915,  577084230, 2712291887,
#          1402622280, 2289569475, 2375459227, 2804410142, 2108870140,
#          2390288946,  845351266, 3403773522, 1765549466, 1377982317,
#          2266085202,  658594337,  806923350,  814729352,  480277280,
#          3915370228, 2665119445, 3057447131, 2726172787, 3199468198,
#            67211016, 1777120151, 3245980413, 3169308371,   47034869,
#          2573036445, 1750656941,  847495810, 1564305956, 4062912045,
#          3437702601,  878086926,  248388206, 3223184047, 3421611031,
#          3828007667,  505787402, 1572609645, 3841754815, 3105427283,
#          1103020237, 3168873677, 1619957796, 1428699393, 3183126815,
#          1588578292, 3402933247,  963122939, 2960181235, 3980793597,
#          3575744033, 2300190771, 4278245407, 2962143515, 2099871300,
#          1497288562,  763262317, 2850907156,  259502106,  397376289,
#          3334033323,   65005394, 2079916285,  226531751, 1069546177,
#          1931411419, 2392662629, 2095382928, 1597660438, 3230856171,
#           135724695, 3255426028, 3942059471, 3281719900, 4179713243,
#           248525303,  974470077, 3299827722,  916371749, 2937490088,
#          1747325726, 2478410124, 2873509411, 1923712883, 2439058893,
#          3968000170,  944814941,  836866042, 1375592671, 2663131960,
#          1337487568, 4072675964,  637249402, 3195401429, 2869750489,
#          2286293322, 1238532342, 2865349317, 1003515746,  686135825,
#          3565920331, 3607152982, 4017828803, 3743791282, 2889912413,
#          2366206796, 3991759729, 3928691447, 1217438140, 2422174064,
#          1740635802,  190763586, 2049486122, 2764937040, 2254615325,
#          2936709045, 1824857061, 2679227485, 4223263421,  882455737,
#          1958207664, 1360714873, 2320864710,  656065682, 3308409314,
#           389091713,  759640457, 1965940653, 2793303970, 1988080269,
#          3108771916, 2548580344,  667643330,  550869207, 2591976415,
#           535940636,  499184574, 1860412362,  985792535,   24034058,
#          1261345937, 4072823211, 4102095954, 1098966116, 3026849599,
#           116117484, 2571519049, 2657910171, 2406695272, 2676974896,
#          2050875398, 3028098004, 1535155233, 2239889760, 1708524711,
#          1055623826, 3159155377, 1381516838,  400992557, 4120789391,
#          4265085749, 1644500657, 2296481514, 2517258671,  475836612,
#          3100974004, 2461674062, 1114733625,  392623415,  457372426,
#          1843496519, 1337043512,  160211471, 3949027350, 3936721942,
#          1549220074, 4272924322, 1173141555,  765115202,  705525852,
#          2373276768,  349653951,  114752280, 4223819740,  921421681,
#           480261313, 3024217697, 1542095821, 3631344096, 1106127105,
#          3460721654, 4248165461, 3055128820, 3685337826, 2171443745,
#           411615833,  224447879, 3512614309, 1402308304, 4243459106,
#          2070341051,   32990699, 1293408168, 3818630975, 2569930194,
#          2474392626, 2531811148,  922353937, 1792437541,  449892768,
#          1013692585,  102917747, 3866763397,  626962861,  924809938,
#          1299278042, 2797826116, 1212312055, 2233882792, 4129627365,
#          1171917619, 2000914949, 3184881264, 1956155946, 3608024631,
#          3950788385,  165875605, 3370670559, 3739540505, 3987576138,
#           755986444, 3896678680,  150178327,  916598651, 2174852460,
#          3908686606, 1119352486, 4254189716, 2631170755, 3458958310,
#          1878970406, 2970422500, 2696371676,   41412358, 2592925375,
#           242021030, 2711639161, 1966267213,  794042092, 2556679951,
#          3511611974, 1749667485, 3468458145, 1475831464, 2154878752,
#          1853743257, 1490487556, 1788881208, 1576729056,  582494170,
#          3575260568, 1237239643, 2678033323,  279342487,  877163591,
#           717895008,  900267693, 3313316140, 3241485549, 3886696023,
#          1699003495, 3368492797,  335215396,  468382849, 2791855932,
#          1464901023,  927973221, 2199191034, 3778996973, 2510258145,
#          3210231429, 2398816833, 4053078254, 2302229195, 2226877731,
#          4127454078, 2515417199, 1837898969, 1204978487, 2727148098,
#          3580374933, 4044591317,   86112826, 4093531014, 2876829959,
#          3928509229,  884248983, 2911562697, 4294424297,   44703113,
#            45959498, 2117440649, 1145875644, 4062613892, 1302113807,
#          1967662754, 3895414813, 1719420603,  992516271, 3759614749,
#          3565911688, 3832696300,  197518702,  694709315, 3739596720,
#          4036018708, 4190330636, 3059516285,  854580748, 4094986940,
#           120186559, 2228117408, 2855854199, 1330424042, 1567201711,
#           186976443,  504805874,  483425153,  419578236, 2321909984,
#          1582538234,  508820258,  479638509,  867833521, 1647776201,
#          2482746649, 3977769089, 3368662550,  743787087, 2455482602,
#           290177973, 1078467943, 1823858552, 3768488777, 2732607746,
#          4113835773,  687818118, 2695659314, 3291576837, 2353761086,
#            24915713, 3536133266, 1109602161, 2578838581, 3063573513,
#          2775356754, 2736778132, 2302787540, 1603675893, 1987054095,
#          4017915335, 1230021492,   61420761, 2419354501, 1098426671,
#          1214314272, 3506819874,  627077981,  860314855, 2670057155,
#          2419123740, 2636785066,  203501956, 2924319407, 2269027295,
#          1947856614, 2220673314, 1041556053, 1564479151, 2738760746,
#          2985612329, 1854515661, 1560335841, 2733105806, 2347849859,
#          3541898390,  340767500,  340766010, 1723038358, 2610942068,
#           659686772,  825708093, 2669067544, 1094297205, 2235227218,
#          3146333050,  652201058, 1256137360, 3785457172, 3753728675,
#          3779177769,  948921579, 3640877589, 3284348988, 3621571298,
#          3647666731, 3572937742, 2460944008,  499027778, 2089657100,
#          2952522666, 3496509856, 2530317902, 2510157466, 4246138474,
#          3230974201,  907546755,  222470603, 2019362408, 3330757652,
#          2262482327, 2288856437, 4253942619,  318313452,  996805260,
#          2168305651,  465915805,  681561020, 2432802417, 3859413698,
#          1092984124,   94408649,  325535154, 3326291401, 2434237751,
#          1482977305, 3882459573,  684128600, 3871586799,  430746108,
#          2327831318, 1616477037, 2120859788, 2837363304, 1953634514,
#          3271791065, 1907132537, 1059515049,  328894820, 2198105624,
#          3903891450, 1478766803,  643251124, 3091307720], dtype=uint32), 429, 0, 0.0))

# %% [markdown]
# Now we want to take a look at those results compared to the "true" situation:

# %%
from astropy.io import ascii
from astropy.table import Table

# reshape the chain output
trace = sampler.chain.reshape(-1, ndim)

# for sanity, store the output in an ASCII file
output = Table(trace)
ascii.write(output, 'trace_ex.txt')

# trim off the burn-in
tr = trace[1000:, :]

# set up a plot
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].axis([0.01, 10, 1e-12, 27])
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].plot(r, Ir, 'black', cb, w0, 'ro', cb, wg, 'go')
ax[0].set_xlabel('angle [arcsec]')
ax[0].set_ylabel('intensity [Jy/arcsec2]')

ax[1].axis([0.0, 1.5, 1e-12, 27])
ax[1].set_yscale('log')
ax[1].set_xlabel('angle [arcsec]')
ax[1].set_ylabel('intensity [Jy/arcsec2]')

# draw randomly from posteriors and plot
for i in np.random.randint(len(tr), size=500):
    amps = tr[i][:]
    ax[0].plot(cb, 10.**amps, color="k", alpha=0.08)
    ax[1].plot(cb, 10.**amps, color="k", alpha=0.08)
    
ax[0].plot(r, Ir, 'black', cb, w0, 'ro', cb, wg, 'go')
ax[1].plot(r, Ir, 'black', cb, w0, 'ro', cb, wg, 'go')
# Out:
# [<matplotlib.lines.Line2D at 0x7fd16da91490>,
#  <matplotlib.lines.Line2D at 0x7fd17c2ce9d0>,
#  <matplotlib.lines.Line2D at 0x7fd17c2cefd0>]
